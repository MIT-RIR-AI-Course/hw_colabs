# %% [markdown]
# # Miniproject 1

# %%
# !pip install pyperplan
# !pip install sympy

# %% [markdown]
# ## Imports and Utilities
# **Note**: these imports and functions are available in catsoop. You do not need to copy them in.

# %%
import os
import time
import numpy as np
from sympy import Symbol, And, Or, satisfiable
from pyperplan.pddl.parser import Parser
from pyperplan import grounding, planner
import tempfile

BLOCKS_DOMAIN = """(define (domain blocks)
    (:requirements :strips :typing)
    (:types block)
    (:predicates 
        (on ?x - block ?y - block)
        (ontable ?x - block)
        (clear ?x - block)
        (handempty)
        (handfull)
        (holding ?x - block)
    )

    (:action pick-up
        :parameters (?x - block)
        :precondition (and
            (clear ?x) 
            (ontable ?x) 
            (handempty)
        )
        :effect (and
            (not (ontable ?x))
            (not (clear ?x))
            (not (handempty))
            (handfull)
            (holding ?x)
        )
    )

    (:action put-down
        :parameters (?x - block)
        :precondition (and 
            (holding ?x)
            (handfull)
        )
        :effect (and 
            (not (holding ?x))
            (clear ?x)
            (handempty)
            (not (handfull))
            (ontable ?x))
        )

    (:action stack
        :parameters (?x - block ?y - block)
        :precondition (and
            (holding ?x) 
            (clear ?y)
            (handfull)
        )
        :effect (and 
            (not (holding ?x))
            (not (clear ?y))
            (clear ?x)
            (handempty)
            (not (handfull))
            (on ?x ?y)
        )
    )

    (:action unstack
        :parameters (?x - block ?y - block)
        :precondition (and
            (on ?x ?y)
            (clear ?x)
            (handempty)
        )
        :effect (and 
            (holding ?x)
            (clear ?y)
            (not (clear ?x))
            (not (handempty))
            (handfull)
            (not (on ?x ?y))
        )
    )
)
"""

BLOCKS_PROBLEM = """(define (problem blocks)
    (:domain blocks)
    (:objects 
        d - block
        b - block
        a - block
        c - block
    )
    (:init 
        (clear a) 
        (on a b) 
        (on b c)
        (on c d)
        (ontable d) 
        (handempty)
    )
    (:goal (and (on d c) (on c b) (on b a)))
)
"""

class SearchAndRescueSimulator:
    """A simulator for a search and rescue problem.

    In search and rescue, a robot must navigate to, pick up, and
    drop off people that are in need of help.

    States are dictionaries with the following attributes:
      "robot": A (row, col) representing the robot's loc.
      "hospital_loc": A (row, col) representing the hospital's loc.
      "carrying": The str name of a person being carried,
        or None, if no person is being carried.
      "people": A dict mapping str people names to (row, col)
        locs. If a person is being carried, they do not
        appear in this dict.
      "state_map": A numpy array of str 'C' and 'W', where 'C'
        represents free space that the robot is allowed to move into,
        and 'W' represents an obstacle(wall).
      "safe_grid": A grid map of boolean values where `True`
        indicate the locations where the robot are allowed to move into.
        In this basic version, any non-wall location is safe to move
        into.

    Actions are strs. The following actions are defined:
      "up" / "down" / "left" / "right" : Moves the robot. The
        robot cannot move into obstacles or off the map.
      "pickup-{person}": If the robot is at the person, and if
        the robot is not already carrying someone, picks them up.
      "dropoff": If the robot is carrying a person, they are
        dropped off at the robot's current location.

    There is a default initial state. See `get_initial_state`
    and `render_state`.

    Example usage:
      simulator = SearchAndRescueSimulator()
      state = simulator.get_initial_state()
      simulator.render_state(state)
      action = "down"
      next_state = simulator.get_next_state(state, action)
    """
    def __init__(self, robot=None, hospital=None,
                 carrying=None, people=None, state_map=None):
        default_state_map = np.array([
            ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
            ['C', 'W', 'W', 'C', 'C', 'W', 'W'],
            ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
            ['C', 'C', 'W', 'C', 'C', 'C', 'C'],
            ['C', 'C', 'W', 'C', 'W', 'C', 'C'],
            ['C', 'C', 'C', 'C', 'C', 'W', 'C'],
            ['C', 'W', 'C', 'C', 'W', 'C', 'C']
        ], dtype=np.str0)
        default_robot = (0, 0)  # top left corner
        default_hospital = (6, 6)  # bottom right corner
        default_carrying = None
        default_people = {
            "p1": (4, 0),
            "p2": (6, 0),
            "p3": (0, 6),
            "p4": (3, 3)
        }

        self.state_map = state_map if state_map is not None else default_state_map
        self.robot = robot if robot is not None else default_robot
        self.hospital = hospital if hospital is not None else default_hospital
        self.carrying = carrying if carrying is not None else default_carrying
        self.people = people if people is not None else default_people

    def get_initial_state(self):
        state = dict(
            state_map=self.state_map,
            robot=self.robot,
            hospital_loc=self.hospital,
            carrying=self.carrying,
            people=self.people
        )
        safe_grid = self.infer_safe_grid(state)
        state.update({"safe_grid" : safe_grid})
        return state

    def infer_safe_grid(self, state):
        # Any non-wall grid is safe
        safe_grid = state["state_map"] == "C"
        return safe_grid

    def draw_env(self, state_arr, state, gt_state=False):
        state_arr[state["state_map"] == "W"] = "##"
        state_arr[state["hospital_loc"]] = "Ho"
        state_arr[state["robot"]] = "Ro"
        return state_arr

    def draw_locs(self, state_arr, state):
        for person, loc in state["people"].items():
            if loc == state["hospital_loc"]:
                continue
            elif loc == state["robot"]:
                person = "R" + person[-1]
            elif loc == state["hospital_loc"]:
                continue
            state_arr[loc] = person
        return state_arr

    def render_state(self, state, gt_state=False):
        height, width = state["state_map"].shape
        state_arr = np.full((height, width), "  ", dtype=object)
        state_arr = self.draw_env(state_arr, state, gt_state=gt_state)
        state_arr = self.draw_locs(state_arr, state)
        # Add padding
        padded_state_arr = np.full((height + 2, width + 2), "##", dtype=object)
        padded_state_arr[1:-1, 1:-1] = state_arr
        state_arr = padded_state_arr
        carrying_str = f"Carrying: {state['carrying']}"
        for row in state_arr:
            print(''.join(row))
        print(carrying_str)
        print()

    def is_valid_location(self, loc_r, loc_c, state):
        if not (0 <= loc_r < state["state_map"].shape[0] and
                0 <= loc_c < state["state_map"].shape[1]):
            print("WARNING: attempted to move out of bounds, action has no effect.")
            return False
        if state["state_map"][loc_r, loc_c] != "C":
            print("WARNING: attempted to move into an obstacle/unsafe region, action has no effect.")
            return False
        return True

    def get_legal_actions(self, state):
        legal_actions = ["up", "down", "left", "right", "dropoff"]
        for person in state["people"]:
            legal_actions.append(f"pickup-{person}")
        return legal_actions

    def get_next_state(self, state, action, dummy_actions=[]):
        legal_actions = self.get_legal_actions(state)
        if action not in legal_actions:
            raise ValueError(f"Unrecognized action {action}. Actions must be one of: {legal_actions}")

        if action in ["up", "down", "left", "right"]:
            dr, dc = {
                "up": (-1, 0),
                "down": (1, 0),
                "left": (0, -1),
                "right": (0, 1),
            }[action]
            r, c = state["robot"]
            if not self.is_valid_location(r + dr, c + dc, state):
                return state
            new_state = self._copy_state(state)
            new_state["robot"] = (r + dr, c + dc)
            return new_state

        elif action.startswith("pickup"):
            person = action.split("-")[1]
            if state["carrying"] is not None:
                print("WARNING: attempted to pick up a person while already carrying someone, action has no effect.")
                return state
            if person not in state["people"] or (state["people"][person] != state["robot"]):
                print("WARNING: attempted to pick up a person not at the robot location, action has no effect.")
                return state
            new_state = self._copy_state(state)
            del new_state["people"][person]
            new_state["carrying"] = person
            return new_state

        elif action == "dropoff":
            if state["carrying"] is None:
                print("WARNING: attempted to dropoff while not carrying anyone, action has no effect.")
                return state
            person = state["carrying"]
            new_state = self._copy_state(state)
            new_state["carrying"] = None
            new_state["people"][person] = state["robot"]

        elif any(action.startswith(dummy_action) for dummy_action in dummy_actions):
            # Do nothing if gets a dummy action.
            return state

        else:
            raise KeyError

        return new_state

    def _copy_state(self, state):
        state = dict(
            state_map=state["state_map"],  # static
            robot=state["robot"],
            hospital_loc=state["hospital_loc"],
            carrying=state["carrying"],
            people=state["people"].copy()
        )
        safe_grid = self.infer_safe_grid(state)
        state["safe_grid"] = safe_grid
        return state


def execute_sar_plan(simulator, plan, state=None, replan_check_fn=None,
                     verbose=True):
    """Execute a plan for search and rescue.

    Args:
      simulator: A SearchAndRescueSimulator.
      plan: A list of action strs, see SearchAndRescueSimulator.
      state: The state from where 'plan' starts to execute.
        If not provided, initial state of 'simulator' is used.
      replan_check_fn: A function that determines whether to stop
        current plan execution and replan or not.
      verbose: If true, print all the states.

    Returns:
      final_state: A SearchAndRescueSimulator state.
      step: Number of steps the plan is executed. Should be equal
        to plan length if there is no replanning.
    """
    step = 0
    state = simulator.get_initial_state() if state is None else state
    if replan_check_fn is None:
        replan_check_fn = lambda sim, s, a: (s, False)
    if verbose:
        simulator.render_state(state)
    for action in plan:
        state = simulator.get_next_state(state, action)
        step += 1
        if verbose:
            print("Executed action:", action)
            simulator.render_state(state)
        state, replan = replan_check_fn(simulator, state, action)
        if replan:
            break
    return state, step

def get_num_delivered(state):
    """
        Returns the number of people located in the hospital.
    """
    num_delivered = 0
    for loc in state["people"].values():
        if loc == state["hospital_loc"]:
            num_delivered += 1
    return num_delivered

def execute_count_num_delivered(simulator, plan, verbose=True):
    """Execute a plan for search and rescue and count the number of
      people delivered.

    Args:
      simulator: A SearchAndRescueSimulator.
      plan: A list of action strs, see SearchAndRescueSimulator.
      verbose: If true, print all the states.

    Returns:
      num_delivered: int
    """
    state, num_step = execute_sar_plan(simulator=simulator, plan=plan, verbose=verbose)
    return get_num_delivered(state)

def run_planning(domain_pddl_str, problem_pddl_str, search_alg_name,
                 heuristic=None):
    """Plan a sequence of actions to solve the given PDDL problem.

    This function is a lightweight wrapper around pyperplan.

    Args:
      domain_pddl_str: A str, the contents of a domain.pddl file.
      problem_pddl_str: A str, the contents of a problem.pddl file.
      search_alg_name: A str, the name of a search algorithm in
        pyperplan. Options: astar, wastar, gbf, bfs, ehs, ids, sat.
      heuristic: A str or a pyperplan `Heuristic` class.
        A str, the name of a heuristic in pyperplan.
          Options: blind, hadd, hmax, hsa, hff, lmcut, landmark.
        A pyperplan `Heuristic` class.
          See: https://github.com/aibasel/pyperplan/blob/main/doc/documentation.md#implementing-new-heuristics

    Returns:
      plan: A list of actions; each action is a pyperplan Operator.
    """
    # Parsing the PDDL
    domain_file = tempfile.NamedTemporaryFile(delete=False)
    problem_file = tempfile.NamedTemporaryFile(delete=False)
    with open(domain_file.name, 'w') as f:
        f.write(domain_pddl_str)
    with open(problem_file.name, 'w') as f:
        f.write(problem_pddl_str)
    parser = Parser(domain_file.name, problem_file.name)
    domain = parser.parse_domain()
    problem = parser.parse_problem(domain)
    os.remove(domain_file.name)
    os.remove(problem_file.name)

    # Ground the PDDL
    task = grounding.ground(problem)

    # Get the search alg
    search_alg = planner.SEARCHES[search_alg_name]

    if heuristic is None:
        return search_alg(task)

    if isinstance(heuristic, str):
        # Get the heuristic from pyperplan
        heuristic_initialized = planner.HEURISTICS[heuristic](task)
    else:
        # Use customized heuristic
        heuristic_initialized = heuristic(task)

    # Run planning
    return search_alg(task, heuristic_initialized)

# %% [markdown]
# ## Let's Make a Plan

# %% [markdown]
# ### Question
# Use `run_planning` to find a plan for the blocks problem defined at the top of the colab file (`BLOCKS_DOMAIN`, `BLOCKS_PROBLEM`).
#
#   The `run_planning` function takes in a PDDL domain string, a PDDL problem string, the name of a search algorithm, and the name of a heuristic (if the search algorithm is informed) or a customized heuristic class. It then uses the Python planning library `pyperplan` to find a plan.
#
#   The plan returned by `run_planning` is a list of pyperplan Operators. You should not need to manipulate these data structures directly in this homework, but if you are curious about the definition, see [here](https://github.com/aibasel/pyperplan/blob/master/pyperplan/task.py#L23).
#
#   The search algs available in pyperplan are: `astar, wastar, gbf, bfs, ehs, ids, sat`. The heuristics available in pyperplan are: `blind, hadd, hmax, hsa, hff, lmcut, landmark`.
#
#   For this question, use the `astar` search algorithm with the `hadd` heuristic.
#
# For reference, our solution is **2** line(s) of code.

# %%
def planning_warmup():
  """Use run_planning to find a plan for the blocks problem
    defined at the top of the colab file (BLOCKS_DOMAIN, BLOCKS_PROBLEM).

    Use the astar search algorithm with the hadd heuristic.

  Returns:
    plan: A list of actions; each action is a pyperplan Operator.    
  """
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
def warmup_test1():
    plan = planning_warmup()
    assert len(plan) == 8
    assert plan[0].name == '(unstack a b)'

warmup_test1()

print('Tests passed.')

# %% [markdown]
# ## Fill in the Blanks

# %% [markdown]
# ### Question
# You've received PDDL domain and problem strings from your boss and you need to make a plan, pronto! Unfortunately, some of the PDDL is missing.
#
#   Here's what you know. What you're trying to model is a newspaper delivery robot. The robot starts out at a "home base" where there are papers that it can pick up. The robot can hold arbitrarily many papers at once. It can then move around to different locations and deliver papers.
#
#   Not all locations want a paper -- the goal is to satisfy all the locations that do want a paper.
#
#   You also know:
#   * There are 6 locations in addition to 1 for the homebase. Locations 1, 2, 3, and 4 want paper; locations 5 and 6 do not.
#   * There are 8 papers at the homebase.
#   * The robot is initially at the homebase with no papers packed.
#
#   Use this description to complete the PDDL domain and problem.
#
#   If you are running into issues debugging the PDDL, look ahead to the next question, where we describe a useful online PDDL editor, and some common PDDL writing pitfalls.
#
#
# For reference, our solution is **89** line(s) of code.

# %%
def pddl_warmup():
    """Creates a PDDL domain and problem strs for newspaper delivery.

    Returns:
      domain: str
      problem: str
    """
    domain_str = """(define (domain newspapers)
    (:requirements :strips :typing)
    (:types loc paper)
    (:predicates 
      (isHomeBase ?loc - loc)
      ; TODO: Add missing predicates!
    )

    (:action pick-up
      :parameters ()    ; TODO: Add missing parameters!
      :precondition (and
        (at ?loc)
        (isHomeBase ?loc)
        (unpacked ?paper)
      )
      :effect (and
        (not (unpacked ?paper))
        (carrying ?paper)
      )
    )

    (:action move
      :parameters (?from - loc ?to - loc)
      :precondition (and
        (at ?from) 
      )
      :effect (and
        (not (at ?from))
        (at ?to)
      )
    )

    (:action deliver
      :parameters (?paper - paper ?loc - loc)
      :precondition (and
        ; TODO: Add missing preconditions!
      )
      :effect (and
        ; TODO: Add missing effects!
      )
    )

)"""

    problem_str = """(define (problem newspapers1) (:domain newspapers)
  (:objects
    loc-0 - loc
    loc-1 - loc
    loc-2 - loc
    loc-3 - loc
    loc-4 - loc
    loc-5 - loc
    loc-6 - loc
    paper-0 - paper
    paper-1 - paper
    paper-2 - paper
    paper-3 - paper
    paper-4 - paper
    paper-5 - paper
    paper-6 - paper
    paper-7 - paper
  )
  (:init 
    (at loc-0)
    (unpacked paper-0)
    ; TODO: Add missing initial atoms!
  )
  (:goal (and
    (satisfied loc-1)
    (satisfied loc-2)
    (satisfied loc-3)
    (satisfied loc-4)
  ))
)"""

    return domain_str, problem_str

# %% [markdown]
# ### Tests

# %%
def warmup_test2():
    domain, problem = pddl_warmup()
    plan = run_planning(domain, problem, "gbf", "hadd")
    assert plan, "Failed to find a plan."
    picked_up_papers = set()
    satisfied_locs = set()
    for op in plan:
        if "pickup" in op.name:
            _, _, paper, _ = op.name.split(" ")
            assert paper not in picked_up_papers, \
                "Should not pick up the same paper twice"
            picked_up_papers.add(paper)
        elif "deliver" in op.name:
            _, loc = op.name.rsplit(" ", 1)
            assert loc.endswith(")")
            loc = loc[:-1]
            assert loc not in satisfied_locs, \
                "Should not deliver to the same place twice"
            satisfied_locs.add(loc)
    assert satisfied_locs == {"loc-1", "loc-2", "loc-3", "loc-4"}

warmup_test2()

print('Tests passed.')

# %% [markdown]
# ## Search and Rescue Warmup 1

# %% [markdown]
# ### Question
# Find the initial robot location in a SearchAndRescueSimulator.
#
# For reference, our solution is **3** line(s) of code.

# %%
def sar_warmup1(simulator):
  """Find the initial robot location in the SearchAndRescueSimulator.

  Args:
    simulator: A SearchAndRescueSimulator.

  Returns:
    robot_loc: A tuple of ints (row, col) representing the robot state.
  """
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
def sar_warmup_test1():
    simulator = SearchAndRescueSimulator()
    robot_loc = sar_warmup1(simulator)
    assert robot_loc == (0, 0)

sar_warmup_test1()

print('Tests passed.')

# %% [markdown]
# ## Search and Rescue Warmup 2

# %% [markdown]
# ### Question
# Check if a row and col have an obstacle in a SearchAndRescueSimulator state.
#
# For reference, our solution is **2** line(s) of code.

# %%
def sar_warmup2(sar_state, row, col):
  """Check if a row and col have an obstacle in a SearchAndRescueSimulator state.

  Args:
    sar_state: A SearchAndRescueSimulator state.
    row: An int.
    col: An int.

  Returns:
    has_obstacle: True if (row, col) has an obstacle in sar_state.
  """
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
def sar_warmup_test2():
    simulator = SearchAndRescueSimulator()
    state = simulator.get_initial_state()
    assert sar_warmup2(state, 0, 0) == False
    assert sar_warmup2(state, 0, 1) == False
    assert sar_warmup2(state, 1, 1) == True
    assert sar_warmup2(state, 1, 2) == True

sar_warmup_test2()

print('Tests passed.')

# %% [markdown]
# ## Search and Rescue Warmup 3

# %% [markdown]
# ### Question
# Hand-code a list of actions that will deliver person 'p1' to the hospital location.
#
# For reference, our solution is **2** line(s) of code.

# %%
def sar_warmup3():
  """Hand-code a list of actions that will deliver person 'p1' to the hospital location.

  Returns:
    actions: A list of str actions that will take person p1 to the hospital loccation.
  """
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
def sar_warmup_test3():
    simulator = SearchAndRescueSimulator()
    plan = sar_warmup3()
    state, num_step = execute_sar_plan(simulator=simulator, plan=plan)
    assert state["people"]["p1"] == (6,6)

sar_warmup_test3()

print('Tests passed.')

# %% [markdown]
# ## Search and Rescue

# %% [markdown]
# ### Question
# Make a planner to solve the search and rescue problem in SearchAndRescueSimulator.
#
# The core function in this planner class is 'get_plan'
# This function does the following:
#     1. Create PDDL domain and problem strings for search and rescue. The operators should work for any grid size, obstacles, people locations, and hospital location.
#     2. Invoke `run_planning` using the given `search_algo` search algorithm with the `heuristic` heuristic.
#     3. Convert the output of run_planning (pyperplan Operators) into actions
#        that can be given to the SearchAndRescueSimulator.
#
#
# For reference, 'get_plan' takes ~1-2 seconds to run with our implementation if using 'gbf' search and 'lmcut' heuristic.
# To get credit on catsoop, make sure that your function finishes in <10 seconds.
#
# **Notes**:
# * In this problem, you will need to construct somewhat complicated strings.  We *strongly* encourage you to read about [Python-3 f-strings](https://www.digitalocean.com/community/tutorials/how-to-use-f-strings-to-create-strings-in-python-3) which make this process much easier than the alternatives.
# * You may find `simulator.render_state` useful for debugging.
# * We also highly recommend printing out the domain and problem after they have been created, and copying them into [editor.planning.domains](http://editor.planning.domains) to check whether it's possible to find a plan. This editor can be helpful for syntax checking.
# * The image in catsoop with the robot and the bears is a faithful depiction of the initial state. For example, the initial locations of the people are: "p1": (4, 0), "p2": (6, 0), "p3": (0, 6), "p4": (3, 3).
# * One part of this problem that may be initially counterintuitive is the way that we'll represent locations in PDDL.
# In the simulator, a location is a tuple of integers. PDDL does not support such representations -- everything needs to be just an object with a string name.
# So to represent a location like (3, 5), we will make a string "l3-5" (where the first character there is a lowercase L), and we'll create an object
# with that name, of type "location". We will also need a way to encode the fact that the robot can only move between adjacent locations in the grid.
# In the simulator, we can compare the numeric values of locations like (3, 5) and (3, 6) to see if they are neighbors.
# But in PDDL, all we have are the objects with string names, and we need to encode everything in terms of predicates.
# So, we will create a predicate `(conn ?v0 - location ?v1 - location ?v2 - direction)`, which says that location `?v0` is connected to locaction `?v1`
# in direction `?v2`. For example, `(conn l3-5 l3-6 right)` might appear in the initial state. We can then use these `conn` predicates in
# the preconditions of a `move` operator to encode the fact that the robot can only move between adjacent locations.
# * We do not recommend modelling the hospital explicitly with special objects / types / predicates. Instead, the goal should be to deliver all people to the hospital_loc, that is, `l6-6`.
# In words, the goal should be "person1 is at l6-6 and person2 is at l6-6 and person3 is at l6-6 and person4 is at l6-6."
#
#
# For reference, our solution is **168** line(s) of code.

# %%
class SearchAndRescuePlanner:
"""A planner for a search and rescue problem.

The core function in this class is 'get_plan'
This function does the following:
    1. Create PDDL domain and problem strings for search and rescue. The operators should work for any grid size, obstacles, people locations, and hospital location.
    2. Invoke `run_planning` using the given `search_algo` search algorithm with the `heuristic` heuristic.
    3. Convert the output of run_planning (pyperplan Operators) into actions
       that can be given to the SearchAndRescueSimulator.

Example Usage:
    simulator = SearchAndRescueSimulator()
    state = simulator.get_initial_state()

    planner = SearchAndRescuePlanner(state, search_algo='astar', heuristic='lmcut')
    plan, plan_time = planner.get_plan()
    state, num_step = execute_sar_plan(simulator=simulator, plan=plan)


'get_plan' Returns:
    plan: A list of actions; each action is a str, see SearchAndRescueSimulator.
    plan_time: Total planning time(sec) used for plan searching.

For reference, 'get_plan' takes ~1-2 seconds to run with our implementation if using 'gbf' search and 'lmcut' heuristic.
"""

    def __init__(self, state, search_algo='astar', heuristic='lmcut'):
        self.start_state = state
        self.search_algo = search_algo
        self.heuristic = heuristic

    def generate_domain_pddl(self, domain_name, added_operators='', added_predicates=''):
        # <<< TODO: fill in missing parts in the PDDL domain below >>>
        operators_str = """(:action move-robot
    :parameters (?from - location ?to - location ?dir - direction)
    :precondition (and
      (conn ?from ?to ?dir)
      ; TODO: write more here
    :effect (and
      ; TODO: write more here
  )
  (:action pickup-person
    :parameters (?person - person ?loc - location)
    :precondition (and
      ; TODO: write more here
    :effect (and
      ; TODO: write more here
  )
  (:action dropoff-person
    :parameters (?person - person ?loc - location)
    :precondition (and
      ; TODO: write more here
    :effect (and
      ; TODO: write more here
  )"""

        # <<< TODO: fill in missing parts in the PDDL domain below >>>
        predicates_str = """(conn ?v0 - location ?v1 - location ?v2 - direction)
    ; TODO: write more here"""

        domain_pddl = f"""(define (domain {domain_name})
    (:requirements :typing)
    (:types person location direction)
    (:constants
      down - direction
      left - direction
      right - direction
      up - direction
    )
    (:predicates
      {predicates_str}
      {added_predicates}
    )
    {operators_str}
    {added_operators}
)"""
        return domain_pddl

    def get_plan(self):
        state, search_algo, heuristic = self.start_state, self.search_algo, self.heuristic
        domain_name, added_predicate, added_operator = self.update_pddl_domain()
        domain_pddl = self.generate_domain_pddl(domain_name, added_operators=added_operator,
                                                added_predicates=added_predicate)
        # Create objects str
        height, width = state["state_map"].shape
        objects_strs = [f"{person} - person" for person in state["people"]]
        # <<< TODO: add object strs for locations >>>
        if state["carrying"] is not None:
            objects_strs.append(f"{state['carrying']} - person")
        objects_str = " ".join(objects_strs)

        # Create init str
        init_strs = self.get_init_strs(state)
        init_str = " ".join(init_strs)

        # Create goal str
        goal_strs = self.get_goal_strs(state)
        goal_str = " ".join(goal_strs)

        problem_pddl = f"""(define (problem searchandrescue) (:domain {domain_name})
      (:objects
      {objects_str}
      )
      (:init 
      {init_str}
      )
      (:goal (and {goal_str}))
    )"""

        start_time = time.time()
        plan = run_planning(domain_pddl, problem_pddl, search_algo, heuristic)
        time_elapsed = time.time() - start_time
        if not plan:
            print("Failed to find a plan.")
            return None, time_elapsed

        # Convert operators to actions
        actions = self.parse_plan(plan)
        return actions, time_elapsed

    def get_init_strs(self, state):
        height, width = state["state_map"].shape
        robot_r, robot_c = state["robot"]
        init_strs = [f"(robot-at l{robot_r}-{robot_c})"]
        for person, (r, c) in state["people"].items():
            init_strs.append(f"(person-at {person} l{r}-{c})")
        if state["carrying"] is not None:
            init_strs.append(f"(carrying {state['carrying']})")
        else:
            init_strs.append("(handsfree)")

        deltas = {
            "up": (-1, 0),
            "down": (1, 0),
            "left": (0, -1),
            "right": (0, 1),
        }
        for r in range(height):
            for c in range(width):
                # Here we're going to add one (conn ...) atom for every pair
                # of adjacent locations.
                for direction, (dr, dc) in deltas.items():
                    if not (0 <= r + dr < height and 0 <= c + dc < width):
                        continue
                    # For example, if r == 0, c == 0, dr == 0, dc == 1, then
                    # this line adds the atom (conn l0-0 l0-1 right).
                    init_strs.append(f"(conn l{r}-{c} l{r + dr}-{c + dc} {direction})")
                # <<< TODO: add more init strs >>>
        return init_strs

    def get_goal_strs(self, state):
        goal_strs = []
        hospital_r, hospital_c = state["hospital_loc"]
        # <<< TODO: add goal strs >>>
        if state["carrying"] is not None:
            # <<< TODO: add goal strs >>>
            pass
        return goal_strs

    def update_pddl_domain(self):
        domain_name = 'searchandrescue'
        added_predicate = ''
        added_operator = ''
        return domain_name, added_predicate, added_operator

    def parse_plan(self, plan):
        actions = []
        for op in plan:
            if "move-robot" in op.name:
                _, direction = op.name[:-1].rsplit(" ", 1)
                action = direction
            elif "pickup-person" in op.name:
                _, person, _ = op.name.split(" ")
                action = f"pickup-{person}"
            else:
                assert "dropoff-person" in op.name
                action = "dropoff"
            actions.append(action)
        return actions

# %% [markdown]
# ### Tests

# %%
def sar_test():
    simulator = SearchAndRescueSimulator()
    planner = SearchAndRescuePlanner(state=simulator.get_initial_state(), search_algo="gbf",
                                        heuristic="lmcut")
    plan, plan_time = planner.get_plan()
    assert execute_count_num_delivered(simulator=simulator, plan=plan, verbose=True) == 4

sar_test()

print('Tests passed.')

# %% [markdown]
# ## Search algorithm & heuristic comparisons

# %% [markdown]
# ### Question
# Let's now compare different search algorithms and
# heuristics on the search and rescue problem above.
#
# The search algs available in pyperplan are: `astar, wastar, gbf, bfs, ehs, ids, sat`.
#
# The heuristics available in pyperplan are: `blind, hadd, hmax, hsa, hff, lmcut, landmark`.
#
# Unfortunately the documentation for pyperplan is limited at the moment, but if you
# are curious to learn more about its internals, the code is open-sourced here:
#
#   https://github.com/aibasel/pyperplan
#
# Choose 8 combinations of (search algorithm, heuristic). For each, record the planning
# duration in seconds for Search and Rescue. If planning takes more than 30 seconds,
# you can kill the process and record "timeout".  Also record the length of the plans.
#
# <div class="question question-multiplechoice">
# <b>Submission Material:</b> In your submitted pdf, please include a table with headers
# "Search Algorithm", "Heuristic", "Duration (s)", and "Plan Length" with 8 rows.
# </div>

# %% [markdown]
# ## Logic_warmup 1

# %% [markdown]
# ### Question
# Use sympy to determine whether the following formula is satisfiable:
# $(\neg x_1 \land x_2) \Rightarrow ((x_2 \lor x_3) \land (x_1 \lor \neg x_3))$.
#
#
# For reference, our solution is **4** line(s) of code.

# %%
def formula1_is_satisfiable():
  """Determines whether the above formula is satisfiable.

  Returns:
    is_satisfiable: A bool indicating whether the formula is satisfiable.
  """
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
assert formula1_is_satisfiable() == True
print('Tests passed.')

# %% [markdown]
# ## Logic_warmup 2

# %% [markdown]
# ### Question
# Use sympy to determine whether the following formula is satisfiable:
# $(x_1 \lor x_2) \land (\neg x_1 \lor \neg x_2) \land (x_1 \lor \neg x_2) \land (\neg x_1 \lor x_2)$.
#
#
# For reference, our solution is **4** line(s) of code.

# %%
def formula2_is_satisfiable():
  """Determines whether the above formula is satisfiable.

  Returns:
    is_satisfiable: A bool indicating whether the formula is satisfiable.
  """
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
assert formula2_is_satisfiable() == False
print('Tests passed.')

# %% [markdown]
# ## Logic_warmup 3

# %% [markdown]
# ### Question
# Prove to yourself that the SAT solver is doing something more clever than enumerating truth tables. Write a formula involving 100 variables for which the SAT solver is able to quickly find a solution. (Hint: assume that the SAT solver is like DPLL. What kinds of formulas would be especially easy for DPLL to satisfy?)
#
# For reference, our solution is **2** line(s) of code.

# %%
def create_large_solvable_formula():
  """Return a sympy formula with at least 100 variables that `satisfiable` can
  quickly solve.

  Returns:
    formula: A sympy logical formula.
  """
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
def test_large_solvable_formula():
    large_formula = create_large_solvable_formula()
    assert len(large_formula.free_symbols) >= 100
    return bool(satisfiable(large_formula))

test_large_solvable_formula()

print('Tests passed.')

# %% [markdown]
# ## Search and Rescue Inference

# %% [markdown]
# ### Question
# Write a program that takes a grid as input and infers unknown values.
#
# Your program should output a new grid with all determinable unknown values replaced with the inferred value. If an unknown value cannot be determined, it should be left unknown.
#
# **Your program should use sympy.**
#
#
# For reference, our solution is **61** line(s) of code.

# %%
def infer_unknown_values(grid):
  """Fill in any unknown values in the grid that can be inferred.

  Args: grid: A list of lists of "F", "U", "S", "W", or "C".
  Returns:
    inferred_grid: A copy of grid with some unknown values replaced.

  Example:
    >> grid = [
    >>   ["F", "U", "C"],
    >>   ["W", "C", "U"],
    >>   ["U", "U", "C"]
    >> ]
    >> infer_unknown_values(grid)
    >> [["F" "S" "C"]
    >>  ["W" "C" "C"]
    >>  ["U" "U" "C"]]
  """
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
assert infer_unknown_values([["U", "F"]]) == [["U", "F"]]


assert infer_unknown_values([["F", "U", "C"], ["S", "C", "U"], ["U", "U", "C"]]) == [["F", "S", "C"], ["S", "C", "C"], ["U", "U", "C"]]


assert infer_unknown_values([["U", "C", "C"], ["S", "C", "U"], ["U", "U", "C"]]) == [["C", "C", "C"], ["S", "C", "C"], ["F", "S", "C"]]


assert infer_unknown_values([["U", "S", "C", "U"], ["U", "U", "C", "U"], ["U", "S", "C", "U"]]) == [["F", "S", "C", "C"], ["U", "U", "C", "C"], ["F", "S", "C", "C"]]


assert infer_unknown_values([["U", "U", "C", "U", "U", "U", "U", "U"], ["C", "U", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "C", "C"], ["U", "U", "U", "U", "U", "U", "C", "C"], ["U", "C", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "F", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "U", "U"]]) == [["C", "C", "C", "U", "U", "U", "U", "U"], ["C", "U", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "C", "C"], ["U", "U", "U", "U", "U", "U", "C", "C"], ["U", "C", "U", "U", "U", "U", "U", "U"], ["U", "U", "U", "F", "U", "U", "U", "U"], ["U", "U", "U", "U", "U", "U", "U", "U"]]


assert infer_unknown_values([["C", "U", "C", "U", "U", "C", "U"], ["U", "W", "W", "U", "C", "W", "W"], ["U", "F", "U", "U", "U", "F", "U"], ["C", "S", "W", "C", "U", "U", "U"], ["U", "U", "W", "U", "W", "U", "U"], ["C", "C", "U", "C", "U", "W", "U"], ["U", "W", "C", "U", "W", "U", "C"]]) == [["C", "C", "C", "C", "C", "C", "C"], ["C", "W", "W", "C", "C", "W", "W"], ["S", "F", "U", "U", "S", "F", "U"], ["C", "S", "W", "C", "U", "U", "U"], ["C", "C", "W", "C", "W", "U", "U"], ["C", "C", "C", "C", "C", "W", "U"], ["C", "W", "C", "C", "W", "C", "C"]]


assert infer_unknown_values([["C", "U", "C", "U", "U", "C", "U"], ["U", "W", "W", "U", "C", "W", "W"], ["U", "F", "U", "U", "U", "F", "U"], ["C", "S", "W", "C", "U", "F", "U"], ["U", "U", "W", "U", "W", "U", "U"], ["C", "C", "U", "C", "U", "W", "F"], ["U", "W", "C", "U", "W", "U", "U"]]) == [["C", "C", "C", "C", "C", "C", "C"], ["C", "W", "W", "C", "C", "W", "W"], ["S", "F", "U", "U", "S", "F", "U"], ["C", "S", "W", "C", "S", "F", "U"], ["C", "C", "W", "C", "W", "U", "U"], ["C", "C", "C", "C", "C", "W", "F"], ["C", "W", "C", "C", "W", "U", "U"]]
print('Tests passed.')

# %% [markdown]
# ## Search and Rescue with Observation

# %% [markdown]
# ### Question
# Formulate the combined PDDL domain for search-and-rescue with observation
#
# For reference, our solution is **79** line(s) of code.
#
# In addition to all of the utilities defined at the top of the colab notebook, the following functions are available in this question environment: `SearchAndRescuePlanner`, `infer_unknown_values`. You may not need to use all of them.

# %%
class POSearchAndRescueSimulator(SearchAndRescueSimulator):
"""A simulator for a search and rescue problem with partial observation.

State dictionary is the same as SearchAndRescueSimulator, with two new entries added:
  "observation_map": A numpy array of str 'F'(fire)/'S'(smoke)/
    'C'(clear)/'W'(wall)/'U'(unknown) observations.
    This map represents the observation that the robot directly
    received from the environment.
  "belief_map": A numpy array of str 'F'(fire)/'S'(smoke)/
    'C'(clear)/'W'(wall)/'U'(unknown) representing the belief of
    world state inferred from 'observation_map'.
Changes to original entries in state dictionary:
  "state_map": A numpy array of str 'F'(fire)/'S'(smoke)/
    'C'(clear)/'W'(wall) representing the actual states in the world.
    New state types are included.

Actions are the same as 'SearchAndRescueSimulator'.
"""

    def __init__(self, observation_map=None, **kwargs):
        super().__init__(**kwargs)
        default_observation_map = np.array([
            ['C', 'U', 'C', 'U', 'U', 'C', 'U'],
            ['U', 'W', 'W', 'U', 'C', 'W', 'W'],
            ['U', 'F', 'U', 'C', 'U', 'U', 'U'],
            ['C', 'S', 'W', 'C', 'U', 'C', 'U'],
            ['U', 'U', 'W', 'U', 'W', 'U', 'C'],
            ['C', 'C', 'U', 'C', 'U', 'W', 'U'],
            ['U', 'W', 'C', 'U', 'W', 'U', 'C']
        ], dtype=np.str0)
        self.observation_map = observation_map if observation_map is not None else default_observation_map

    def infer_safe_grid(self, state):
        """
            Please make sure that this function is not accessing the "state_map", as
            this is a partially observable setting where real underlying state is
            unknown to the agent. The agent only has access to observation map.
        """
        # <<< TODO: return safe grids that the robot believe to be safe >>>
        safe_grid = None
        return safe_grid

    def update_observation(self, state, observation_map):
        belief_map = np.asarray(infer_unknown_values(observation_map))  # use the program from (2.6)
        state.update({
            "observation_map": observation_map,
            "belief_map": belief_map
        })
        safe_grid = self.infer_safe_grid(state)
        state.update({"safe_grid": safe_grid})
        return state

    def get_initial_state(self):
        state = dict(
            state_map=self.state_map,
            robot=self.robot,
            hospital_loc=self.hospital,
            carrying=self.carrying,
            people=self.people,
        )
        state = self.update_observation(state, self.observation_map)
        return state

    def draw_env(self, state_arr, state, gt_state=False):
        # override `draw_env` fn, draw fire(XX), smoke(||) and unknown(??) grids
        # Note: By default, this function renders the belief state.
        if gt_state:
            state_arr[state["state_map"] == 'W'] = "##"
            state_arr[state["state_map"] == 'F'] = "XX"
            state_arr[state["state_map"] == 'S'] = "||"
        else:
            state_arr[state["belief_map"] == 'W'] = "##"
            state_arr[state["belief_map"] == 'F'] = "XX"
            state_arr[state["belief_map"] == 'S'] = "||"
            state_arr[state["belief_map"] == 'U'] = "??"
        state_arr[state["hospital_loc"]] = "Ho"
        state_arr[state["robot"]] = "Ro"
        return state_arr

    def _copy_state(self, state):
        state = dict(
            state_map=state["state_map"],  # static
            robot=state["robot"],
            hospital_loc=state["hospital_loc"],
            carrying=state["carrying"],
            people=state["people"].copy(),
            observation_map=state["observation_map"].copy(),
            belief_map=state["belief_map"].copy(),
        )
        safe_grid = self.infer_safe_grid(state)
        state["safe_grid"] = safe_grid
        return state

# %% [markdown]
# ### Tests

# %%
def posar_test():
    simulator = POSearchAndRescueSimulator()
    plan, plan_time = POSearchAndRescuePlanner(state=simulator.get_initial_state(), search_algo='gbf',
                                                    heuristic='lmcut').get_plan()
    assert execute_count_num_delivered(simulator=simulator, plan=plan, verbose=True) == 4

posar_test()

print('Tests passed.')

# %% [markdown]
# ## Search and Rescue with Replanning

# %% [markdown]
# ### Question
# Let's assume that the robot can make new observations while moving, so that it can check whether a grid location is safe and then move into that location.
# We assume that the robot can make observation of a grid when it's next to that location(above, below, left, right). The planner will search for a plan which involves information gathering
# operators. After such a plan is found, the plan will be partially executed, and replans when an observation to the environement is made.
#
# Fill in the missing part of `POSearchAndRescuePlanner_lookadjacent`. Feel free to add one or more predicates and operators if you feel necessary.
# We've provided some helper functions to parse new operators into simulator actions. If you prefer using your own predicate formulation, remember to change that in simulator as well.
#
# For reference, our solution is **98** line(s) of code.
#
# In addition to all of the utilities defined at the top of the colab notebook, the following functions are available in this question environment: `POSearchAndRescueSimulator`, `SearchAndRescuePlanner`, `infer_unknown_values`. You may not need to use all of them.

# %%
class POSearchAndRescuePlanner_lookadjacent(SearchAndRescuePlanner):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def update_pddl_domain(self):
        """
            Returns:
                'domain_name': Domain name of this pddl domain,
                'added_predicate': New predicates.
                    e.g. added_predicate = '(newpredicate1 ?v0 - type1) (newpredicate2 ?v0 - type2)'
                'added_operator':  New operators.
                    e.g. added_operator = '(:action foo
                                                :parameters (?v0 - bar ... )
                                                :precondition (and ... )
                                                :effect (and ... ))'
        """
        domain_name = 'looksearchandrescue'
        added_predicate = '' # <<< TODO: add new predicate >>
        added_operator = """(:action look
    :parameters (?from - location ?to - location ?dir - direction)
    :precondition (and
        ; TODO: write more here.
    )
    :effect (and 
        ; TODO: write more here.
    ))"""
        return domain_name, added_predicate, added_operator

    def parse_plan(self, plan):
        actions = []
        for op in plan:
            if "move-robot" in op.name:
                _, direction = op.name[:-1].rsplit(" ", 1)
                action = direction
            elif "pickup-person" in op.name:
                _, person, _ = op.name.split(" ")
                action = f"pickup-{person}"
            elif "look" in op.name:
                cur_rc, to_rc = op.name[:-1].split(" ")[1:-1]
                cur_r, cur_c = cur_rc.split('-')
                to_r, to_c = to_rc.split('-')
                action = f"look-{cur_r}-{cur_c}-{to_r}-{to_c}"
            else:
                assert "dropoff-person" in op.name
                action = "dropoff"
            actions.append(action)
        return actions

    def get_init_strs(self, state):
        init_strs = super().get_init_strs(state)
        # <<< TODO: add init strs here >>>
        return init_strs

# %% [markdown]
# ### Tests

# %%
def execute_replan_posar_test1():
    observation_map = np.array([
        ['C', 'U', 'C', 'U', 'U', 'C', 'U'],
        ['C', 'W', 'W', 'C', 'C', 'W', 'W'],
        ['C', 'U', 'C', 'C', 'U', 'U', 'U'],
        ['C', 'C', 'W', 'C', 'U', 'C', 'C'],
        ['U', 'C', 'W', 'U', 'W', 'U', 'C'],
        ['U', 'U', 'C', 'C', 'U', 'W', 'C'],
        ['U', 'W', 'C', 'U', 'W', 'U', 'C']
    ], dtype=np.str0)
    state_map = np.array([
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'W', 'W', 'C', 'C', 'W', 'W'],
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'C', 'W', 'C', 'C', 'C', 'C'],
        ['S', 'C', 'W', 'C', 'W', 'C', 'C'],
        ['F', 'S', 'C', 'C', 'C', 'W', 'C'],
        ['S', 'W', 'C', 'C', 'W', 'C', 'C']
    ], dtype=np.str0)
    people = {
        "p1": (5, 2),
        "p2": (2, 3)
    }
    simulator = POSearchAndRescueSimulator_lookadjacent(observation_map=observation_map,
                                                        state_map=state_map, people=people)
    planner = POSearchAndRescuePlanner_lookadjacent
    search_algo = 'astar'
    heuristic = 'lmcut'
    success, total_plan_time, total_step, replan_cnt = execute_replan_posar(simulator, len(people.keys()), planner=planner,
                                                                      search_algo=search_algo, heuristic=heuristic)
    print(f"Search: {search_algo}\t Heuristic: {heuristic}\t Number of target(s): {len(people.keys())}")
    print(f"Total planning time: {total_plan_time}\t Total plan length: {total_step}\t Replan Cnt {replan_cnt}")
    assert success

execute_replan_posar_test1()


def execute_replan_posar_test2():
    observation_map = np.array([
        ['C', 'U', 'C', 'U', 'U', 'C', 'U'],
        ['C', 'W', 'W', 'U', 'C', 'W', 'W'],
        ['C', 'U', 'U', 'C', 'U', 'U', 'U'],
        ['C', 'C', 'W', 'C', 'C', 'C', 'C'],
        ['U', 'C', 'W', 'C', 'W', 'U', 'C'],
        ['U', 'U', 'C', 'C', 'U', 'W', 'C'],
        ['U', 'W', 'C', 'U', 'W', 'U', 'C']
    ], dtype=np.str0)
    state_map = np.array([
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'W', 'W', 'C', 'C', 'W', 'W'],
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'C', 'W', 'C', 'C', 'C', 'C'],
        ['C', 'C', 'W', 'C', 'W', 'C', 'C'],
        ['C', 'C', 'C', 'C', 'C', 'W', 'C'],
        ['C', 'W', 'C', 'C', 'W', 'C', 'C']
    ], dtype=np.str0)
    people = {
        "p1": (5, 2),
    }
    simulator = POSearchAndRescueSimulator_lookadjacent(observation_map=observation_map,
                                                        state_map=state_map, people=people)
    planner = POSearchAndRescuePlanner_lookadjacent
    search_algo = 'astar'
    heuristic = 'lmcut'
    success, total_plan_time, total_step, replan_cnt = execute_replan_posar(simulator, len(people.keys()),
                                                                            planner=planner,
                                                                            search_algo=search_algo,
                                                                            heuristic=heuristic)
    print(f"Search: {search_algo}\t Heuristic: {heuristic}\t Number of target(s): {len(people.keys())}")
    print(f"Total planning time: {total_plan_time}\t Total plan length: {total_step}\t Replan Cnt {replan_cnt}")
    assert success
    assert total_step == 19

execute_replan_posar_test2()


def execute_replan_posar_test3():
    observation_map = np.array([
        ['C', 'U', 'C', 'U', 'U', 'C', 'U'],
        ['C', 'W', 'W', 'U', 'C', 'W', 'W'],
        ['C', 'U', 'U', 'C', 'U', 'U', 'U'],
        ['U', 'C', 'W', 'C', 'C', 'C', 'C'],
        ['U', 'U', 'W', 'C', 'W', 'U', 'C'],
        ['U', 'U', 'C', 'C', 'U', 'W', 'C'],
        ['U', 'W', 'C', 'U', 'W', 'U', 'C']
    ], dtype=np.str0)
    state_map = np.array([
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'W', 'W', 'C', 'C', 'W', 'W'],
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'C', 'W', 'C', 'C', 'C', 'C'],
        ['S', 'C', 'W', 'C', 'W', 'C', 'C'],
        ['F', 'S', 'C', 'C', 'C', 'W', 'C'],
        ['S', 'W', 'C', 'C', 'W', 'C', 'C']
    ], dtype=np.str0)
    people = {
        "p1": (5, 2),
    }
    simulator = POSearchAndRescueSimulator_lookadjacent(observation_map=observation_map,
                                                        state_map=state_map, people=people)
    planner = POSearchAndRescuePlanner_lookadjacent
    search_algo = 'astar'
    heuristic = 'lmcut'
    success, total_plan_time, total_step, replan_cnt = execute_replan_posar(simulator, len(people.keys()),
                                                                            planner=planner,
                                                                            search_algo=search_algo,
                                                                            heuristic=heuristic)
    print(f"Search: {search_algo}\t Heuristic: {heuristic}\t Number of target(s): {len(people.keys())}")
    print(f"Total planning time: {total_plan_time}\t Total plan length: {total_step}\t Replan Cnt {replan_cnt}")
    assert success
    assert total_step == 20

execute_replan_posar_test3()

print('Tests passed.')

# %% [markdown]
# ## Play with the heuristic value

# %% [markdown]
# ### Question
# Take a look at the plan produced by POSearchAndRescuePlanner_lookadjacent, which path does it select and how many replans took place? Is there another path that is actually of lower cost if the state is fully observable?
#
# To tweak the behaviour of the planner, one possible way is to change the heuristic function provided. pyperplan allows user defined heuristic function.
# e.g.
#
#
#     from pyperplan.heuristics.lm_cut import LmCutHeuristic
#     class Modified_LmCutHeuristic(LmCutHeuristic):
#         def __init__(self, task):
#             super().__init__(task)
#
#         def __call__(self, node):
#             lmcut_val = super().__call__(node)
#             if node.action is not None and 'look' in node.action.name:
#                 modified_lmcut_val = # change the heuristic value here
#             return modified_lmcut_val
#     execute_replan_posar(simulator, len(people.keys()), planner=planner, search_algo=search_algo, heuristic=Modified_LmCutHeuristic)
#
# If you are interested, try playing with the heuristic value and see what happens.
# Is your modified heuristic still admissible? Is it guaranteed to find a better path?
#
#
# For reference, our solution is **44** line(s) of code.
#
# In addition to all of the utilities defined at the top of the colab notebook, the following functions are available in this question environment: `POSearchAndRescuePlanner_lookadjacent`, `POSearchAndRescueSimulator`, `SearchAndRescuePlanner`, `infer_unknown_values`. You may not need to use all of them.

# %%
def create_customized_heuristic():
    from pyperplan.heuristics.lm_cut import LmCutHeuristic
    class Modified_LmCutHeuristic(LmCutHeuristic):
        def __init__(self, task):
            super().__init__(task)

        def __call__(self, node):
            # <<< TODO: Change the heuristic value here >>>
            pass
    return Modified_LmCutHeuristic

# %% [markdown]
# ## Search and Rescue with Replanning, in two stages

# %% [markdown]
# ### Question
# For the previous formulation, what is the running time when using `astar` with `lmcut` heuristic? How is the running time scaling up w.r.t the number of people and the plan horizon?
# Is there a way to quickly find a plan on some relaxed version of the test problem?
#
# Now let's consider another formulation. We will try to solve the problem in two stages. Specifically, we will first try to find a **guaranteed** safe path, without planning to make observations.
# If such path exists, mission complete! If not, we will try to look at a relaxed version of the problem. The robot will be optimistic, assuming all unknown grids are 'clear'. By making such assumption,
# it is allowed to make plans that will go through unknown squares. However, after each movement, the robot will get an observation of the neighbouring grids, and replan if something unexpected observed.
# For example, when there's a smoke in a neighbouring grid.
#
# Compare the resulting paths to the previous formulation, especially on the last test map(in Colab Notebook). Which one is getting a shorter path? What's the reason that lead to such difference?
#
#
# For reference, our solution is **54** line(s) of code.
#
# In addition to all of the utilities defined at the top of the colab notebook, the following functions are available in this question environment: `POSearchAndRescueSimulator`, `SearchAndRescuePlanner`, `infer_unknown_values`. You may not need to use all of them.

# %%
def execute_replan_posar_twostage(simulator, num_people, planner,
                         search_algo='astar', heuristic='lmcut',
                         verbose=True, max_replan_cnt=15):
  raise NotImplementedError("Implement me!")

# %% [markdown]
# ### Tests

# %%
def execute_replan_posar_twostage_test1():
    observation_map = np.array([
        ['C', 'U', 'C', 'U', 'U', 'C', 'U'],
        ['C', 'W', 'W', 'U', 'C', 'W', 'W'],
        ['C', 'U', 'U', 'C', 'U', 'U', 'U'],
        ['U', 'C', 'W', 'U', 'U', 'C', 'C'],
        ['U', 'U', 'W', 'C', 'W', 'U', 'C'],
        ['U', 'U', 'C', 'U', 'U', 'W', 'C'],
        ['U', 'W', 'C', 'U', 'W', 'U', 'C']
    ], dtype=np.str0)
    state_map = np.array([
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'W', 'W', 'C', 'C', 'W', 'W'],
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'C', 'W', 'C', 'C', 'C', 'C'],
        ['S', 'C', 'W', 'C', 'W', 'C', 'C'],
        ['F', 'S', 'C', 'C', 'C', 'W', 'C'],
        ['S', 'W', 'C', 'C', 'W', 'C', 'C']
    ], dtype=np.str0)
    people = {
        "p1": (5, 2),
        # "p2": (2, 3)
    }
    simulator = POSearchAndRescueSimulator(observation_map=observation_map,
                                                    state_map=state_map,
                                                    people=people)
    planner = POSearchAndRescuePlanner
    search_algo = 'astar'
    heuristic = 'lmcut'
    success, total_plan_time, total_step, replan_cnt = execute_replan_posar_twostage(simulator, len(people.keys()),
                                                                            planner=planner,
                                                                            search_algo=search_algo,
                                                                            heuristic=heuristic)
    print(f"Search: {search_algo}\t Heuristic: {heuristic}\t Number of target(s): {len(people.keys())}")
    print(f"Total planning time: {total_plan_time}\t Total plan length: {total_step}\t Replan Cnt {replan_cnt}")
    assert success

execute_replan_posar_twostage_test1()


def execute_replan_posar_twostage_test2():
    observation_map = np.array([
        ['C', 'U', 'C', 'U', 'U', 'C', 'U'],
        ['C', 'W', 'W', 'U', 'C', 'W', 'W'],
        ['C', 'U', 'U', 'U', 'U', 'U', 'U'],
        ['C', 'C', 'W', 'U', 'U', 'C', 'C'],
        ['U', 'C', 'W', 'U', 'W', 'U', 'C'],
        ['U', 'U', 'C', 'U', 'U', 'W', 'C'],
        ['U', 'W', 'C', 'U', 'W', 'U', 'C']
    ], dtype=np.str0)
    state_map = np.array([
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'W', 'W', 'C', 'C', 'W', 'W'],
        ['C', 'C', 'C', 'C', 'C', 'C', 'C'],
        ['C', 'C', 'W', 'S', 'S', 'C', 'C'],
        ['C', 'C', 'W', 'F', 'W', 'C', 'C'],
        ['C', 'C', 'C', 'S', 'C', 'W', 'C'],
        ['C', 'W', 'C', 'C', 'W', 'C', 'C']
    ], dtype=np.str0)
    people = {
        "p1": (5, 2),
        "p2": (2, 3)
    }
    simulator = POSearchAndRescueSimulator(observation_map=observation_map,
                                                    state_map=state_map,
                                                    people=people)
    planner = POSearchAndRescuePlanner
    search_algo = 'astar'
    heuristic = 'lmcut'
    success, total_plan_time, total_step, replan_cnt = execute_replan_posar_twostage(simulator, len(people.keys()),
                                                                            planner=planner,
                                                                            search_algo=search_algo,
                                                                            heuristic=heuristic)
    print(f"Search: {search_algo}\t Heuristic: {heuristic}\t Number of target(s): {len(people.keys())}")
    print(f"Total planning time: {total_plan_time}\t Total plan length: {total_step}\t Replan Cnt {replan_cnt}")
    assert success

execute_replan_posar_twostage_test2()

print('Tests passed.')
